# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
df_cariac_failure = pd.read_csv("/kaggle/input/byte2beat/Datasets/Cardiac Failure/cardiac_failure_processed.csv")
df_cario_base = pd.read_csv("/kaggle/input/byte2beat/Datasets/Cardiac Failure/cardio_base.csv")


df_ecg = pd.read_csv("/kaggle/input/byte2beat/Datasets/ECG Timeseries/ecg_timeseries.csv", nrows=5)
df_heart = pd.read_csv("/kaggle/input/byte2beat/Datasets/Heart Attack/heart_processed.csv")

# %%
df_preview.head()
